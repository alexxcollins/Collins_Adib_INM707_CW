# %%
from Agent import train
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.7.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
train()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11448\3364925475.py in <module>
# ----> 1 train()
#
# D:\City University of London\MSc Artificial intelligence\Term 2\INM707 Deep Reinforcement Learning\Coursework\CW code\Collins_Adib_INM707_CW\Advanced RL\Agent.py in train()
#     116
#     117         # perform move and get new state
# --> 118         reward, done, score = game.play_step(final_move)
#     119         state_new = agent.get_state(game)
#     120
#
# D:\City University of London\MSc Artificial intelligence\Term 2\INM707 Deep Reinforcement Learning\Coursework\CW code\Collins_Adib_INM707_CW\Advanced RL\Game.py in play_step(self, action)
#      96         # 5. update ui and clock
#      97         self._update_ui()
# ---> 98         self.clock.tick(SPEED)
#      99         # 6. return game over and score
# ...
