# %%
from agent import Agent
from helper import plot
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.7.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
plot_scores = []
plot_mean_scores = []
total_score = 0
record = 0
epsilons = []
agent = Agent(double_dqn=True)
i_episode = 0
#agent.load_model('model_v2.pth')
#agent.load_model('model_v3.pth')

while True:
    i_episode += 1
    state = agent.get_observation()
    action = agent.e_greedy_action(state)
    reward, done, score = agent.game.play_step(action)
    new_state = agent.get_observation()
    # train short memory
    agent.train_step(state, action, reward, new_state, done)

    # remember
    agent.remember(state, action, reward, new_state, done)
    
    agent.update_policy()
    
    if done:
        # train long memory, plot result
        agent.game.reset()
        agent.n_games += 1
        
        states, actions, rewards, new_states, dones = agent.get_memory_sample()
        agent.train_step(states, actions, rewards, new_states, dones)

        if score > record:
            record = score
            agent.save_model('ddqn_model_v0.pth')

        

        plot_scores.append(score)
        total_score += score
        mean_score = total_score / agent.n_games
        plot_mean_scores.append(mean_score)
        #print('Game', agent.n_games, 'Score', score, 'Record:', record, 'Mean Score: ', mean_score)
        plot(plot_scores,plot_mean_scores)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7032\394885062.py in <module>
#      13     state = agent.get_observation()
#      14     action = agent.e_greedy_action(state)
# ---> 15     reward, done, score = agent.game.play_step(action)
#      16     new_state = agent.get_observation()
#      17     # train short memory
#
# D:\City University of London\MSc Artificial intelligence\Term 2\INM707 Deep Reinforcement Learning\Coursework\CW code\Collins_Adib_INM707_CW\Advanced RL\game.py in play_step(self, action)
#     121             if event.type == pygame.QUIT:
#     122                 pygame.quit()
# --> 123                 quit()
#     124
#     125         # 2. move
#
# NameError: name 'quit' is not defined
