# %%
from agent import Agent
from helper import plot
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.7.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
plot_scores = []
plot_mean_scores = []
total_score = 0
record = 0
epsilons = []
agent = Agent(double_dqn=True)
agent.load_model('ddqn_model_v0.pth')

while True:
    state = agent.get_observation()
    action = agent.choose_action(state)
    reward, done, score = agent.game.play_step(action)
    new_state = agent.get_observation()
    # remember
    agent.remember(state, action, reward, new_state, done)
            
    if done:
        # train long memory, plot result
        agent.game.reset()
        
        states, actions, rewards, new_states, dones = agent.get_memory_sample()
        agent.learn(states, actions, rewards, new_states, dones)

        if score > record:
            record = score
            agent.save_model('ddqn_model_v0.pth')

        

        plot_scores.append(score)
        total_score += score
        mean_score = total_score / agent.number_episodes
        plot_mean_scores.append(mean_score)
        #print('Game', agent.n_games, 'Score', score, 'Record:', record, 'Mean Score: ', mean_score)
        plot(plot_scores,plot_mean_scores)
        


agent.game.end_game()
# Out:
# => loading checkpoint...
# done !
# pred tensor([[ 1.3589, -3.0486,  0.6935]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3589, -3.0486,  0.6935]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3483, -3.2798,  0.6914]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3483, -3.2798,  0.6914]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3334, -3.4880,  0.6897]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3334, -3.4880,  0.6897]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3152, -3.6755,  0.6882]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3152, -3.6755,  0.6882]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.2951, -3.8444,  0.6873]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.2951, -3.8444,  0.6873]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.2742, -3.9967,  0.6870]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.2742, -3.9967,  0.6870]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.2532, -4.1340,  0.6868]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.2532, -4.1340,  0.6868]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.2330, -4.2577,  0.6867]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.2330, -4.2577,  0.6867]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.2144, -4.3691,  0.6867]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.2144, -4.3691,  0.6867]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.1981, -4.4696,  0.6866]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.1981, -4.4696,  0.6866]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.1843, -4.5601,  0.6865]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.1843, -4.5601,  0.6865]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.1736, -4.6418,  0.6863]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.1736, -4.6418,  0.6863]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.1660, -4.7155,  0.6860]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.1660, -4.7155,  0.6860]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.1616, -4.7819,  0.6855]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.1616, -4.7819,  0.6855]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.1602, -4.8419,  0.6850]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.1602, -4.8419,  0.6850]], grad_fn=<AddmmBackward0>)
# pred tensor([[-2.6604, -2.9563,  2.6203]], grad_fn=<AddmmBackward0>)
# target tensor([[-2.6604, -2.9563,  2.6203]], grad_fn=<AddmmBackward0>)
# pred tensor([[  1.7589, -10.2788,   0.4187]], grad_fn=<AddmmBackward0>)
# target tensor([[  1.7589, -10.2788,   0.4187]], grad_fn=<AddmmBackward0>)
# pred tensor([[  1.7819, -10.3297,   0.3563]], grad_fn=<AddmmBackward0>)
# target tensor([[  1.7819, -10.3297,   0.3563]], grad_fn=<AddmmBackward0>)
# pred tensor([[  1.7993, -10.3754,   0.3002]], grad_fn=<AddmmBackward0>)
# target tensor([[  1.7993, -10.3754,   0.3002]], grad_fn=<AddmmBackward0>)
# pred tensor([[  1.8107, -10.4165,   0.2498]], grad_fn=<AddmmBackward0>)
# target tensor([[  1.8107, -10.4165,   0.2498]], grad_fn=<AddmmBackward0>)
# pred tensor([[  1.8158, -10.4535,   0.2045]], grad_fn=<AddmmBackward0>)
# target tensor([[  1.8158, -10.4535,   0.2045]], grad_fn=<AddmmBackward0>)
# pred tensor([[  1.1421, -10.6525,   0.5551]], grad_fn=<AddmmBackward0>)
# target tensor([[  1.1421, -10.6525,   0.5551]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.0500, -9.9393, -1.0144]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.0500, -9.9393, -1.0144]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.0268, -9.9609, -1.0382]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.0268, -9.9609, -1.0382]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.0079, -9.9804, -1.0598]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.0079, -9.9804, -1.0598]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 0.9940, -9.9979, -1.0795]], grad_fn=<AddmmBackward0>)
# target tensor([[ 0.9940, -9.9979, -1.0795]], grad_fn=<AddmmBackward0>)
# pred tensor([[  0.9853, -10.0135,  -1.0975]], grad_fn=<AddmmBackward0>)
# target tensor([[  0.9853, -10.0135,  -1.0975]], grad_fn=<AddmmBackward0>)
# pred tensor([[-2.6902, -9.0966,  0.2858]], grad_fn=<AddmmBackward0>)
# target tensor([[-2.6902, -9.0966,  0.2858]], grad_fn=<AddmmBackward0>)
# pred tensor([[  0.8411, -10.6408,  -0.3028]], grad_fn=<AddmmBackward0>)
# target tensor([[  0.8411, -10.6408,  -0.3028]], grad_fn=<AddmmBackward0>)
# pred tensor([[  0.8315, -10.6494,  -0.2699]], grad_fn=<AddmmBackward0>)
# target tensor([[  0.8315, -10.6494,  -0.2699]], grad_fn=<AddmmBackward0>)
# pred tensor([[  0.8254, -10.6571,  -0.2405]], grad_fn=<AddmmBackward0>)
# target tensor([[  0.8254, -10.6571,  -0.2405]], grad_fn=<AddmmBackward0>)
# pred tensor([[  0.
], grad_fn=<AddmmBackward0>)
# target tensor([[ 0.7156, -2.3300, -1.2729]], grad_fn=<AddmmBackward0>)
# pred tensor([[-2.7440, -2.0890,  0.4219]], grad_fn=<AddmmBackward0>)
# target tensor([[-2.7440, -2.0890,  0.4219]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 0.5937, -9.2537,  1.6820]], grad_fn=<AddmmBackward0>)
# target tensor([[ 0.5937, -9.2537,  1.6820]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.4182, -1.9286, -4.7676]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.4182, -1.9286, -4.7676]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.5304, -3.1925, -0.2721]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.5304, -3.1925, -0.2721]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.5035, -3.1905, -0.2399]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.5035, -3.1905, -0.2399]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.4679, -3.1881, -0.2104]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.4679, -3.1881, -0.2104]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.4263, -3.1854, -0.1835]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.4263, -3.1854, -0.1835]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3817, -3.1826, -0.1589]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3817, -3.1826, -0.1589]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3369, -3.1798, -0.1366]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3369, -3.1798, -0.1366]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3678, -3.4517,  0.8063]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3678, -3.4517,  0.8063]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3848, -4.8104, -0.0436]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3848, -4.8104, -0.0436]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3588, -4.8089, -0.0267]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3588, -4.8089, -0.0267]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3383, -4.8077, -0.0117]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3383, -4.8077, -0.0117]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3239e+00, -4.8070e+00,  1.8052e-03]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3239e+00, -4.8070e+00,  1.8052e-03]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3159, -4.8067,  0.0138]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3159, -4.8067,  0.0138]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3142, -4.8069,  0.0244]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3142, -4.8069,  0.0244]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3183, -4.8076,  0.0339]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3183, -4.8076,  0.0339]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3272, -4.8087,  0.0422]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3272, -4.8087,  0.0422]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3401, -4.8100,  0.0496]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3401, -4.8100,  0.0496]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3557, -4.8115,  0.0561]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3557, -4.8115,  0.0561]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3728, -4.8132,  0.0619]], grad_fn=<AddmmBackward0>)
# target tensor([[ 1.3728, -4.8132,  0.0619]], grad_fn=<AddmmBackward0>)
# pred tensor([[ 1.3902, -4.8148,  0.0670]], grad_fn=<AddmmBackward0>)
# target
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10076\671394656.py in <module>
#      15     new_state = agent.get_observation()
#      16     # train short memory
# ---> 17     agent.train_step(state, action, reward, new_state, done)
#      18
#      19     # remember
#
# D:\City University of London\MSc Artificial intelligence\Term 2\INM707 Deep Reinforcement Learning\Coursework\CW code\Collins_Adib_INM707_CW\Advanced RL\agent.py in train_step(self, state, action, reward, next_state, done)
#     238             target = self.policy_net(state)
#     239             print('pred', pred)
# --> 240             print('target', target)
#     241             for idx in range(len(done)):
#     242                 Q_new = reward[idx]
#
# ~\anaconda3\envs\ailab\lib\site-packages\torch\_tensor.py in __repr__(self)
#     247             return handle_torch_function(Tensor.__repr__, (self,), self)
#     248         # All strings are unicode in Python 3.
# --> 249         return torch._tensor_str._str(self)
#     250
#     251     def backward(self, gradient=None, retain_graph=None, create_graph=False, inputs=None):
#
# ~\anaconda3\envs\ailab\lib\site-packages\torch\_tensor_str.py in _str(self)
#     413 def _str(self):
#     414     with torch.no_grad():
# --> 415         return _str_intern(self)
#
# ~\anaconda3\envs\ailab\lib\site-packages\torch\_tensor_str.py in _str_intern(inp)
#     388                     tensor_str = _tensor_str(self.to_dense(), indent)
#     389                 else:
# --> 390                     tensor_str = _tensor_str(self, indent)
#     391
#     392     if self.layout != torch.strided:
#
# ~\anaconda3\envs\ailab\lib\site-packages\torch\_tensor_str.py in _tensor_str(self, indent)
#     249         return _tensor_str_with_formatter(self, indent, summarize, real_formatter, imag_formatter)
#     250     else:
# --> 251         formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     252         return _tensor_str_with_formatter(self, indent, summarize, formatter)
#     253
#
# ~\anaconda3\envs\ailab\lib\site-packages\torch\_tensor_str.py in __init__(self, tensor)
#      97             nonzero_finite_abs = nonzero_finite_vals.abs().double()
#      98             nonzero_finite_min = nonzero_finite_abs.min().double()
# ---> 99             nonzero_finite_max = nonzero_finite_abs.max().double()
#     100
#     101             for value in nonzero_finite_vals:
#
# KeyboardInterrupt:
